# %%
import pandas as pd
import numpy as np
import dotenv
from incawrapper import dataschemas

# %%
# import environment variables
INCA_base_directory = dotenv.get_key(dotenv.find_dotenv(), "INCA_base_directory")

# %%
xl = pd.ExcelFile("./Literature data/Arabidopsis thaliana Allen 2014/pnas.1319485111.sd01.xls")

# %%
xl.sheet_names
# Out:
# ['Overview',
#  'MRM Parameters',
#  'GCMS fragments',
#  'LCMSMS transitions',
#  'UDGP and ADPG Transitions',
#  'Labeled UDPG and ADPG',
#  'Metabolite recovery',
#  'PGA',
#  'DHAP',
#  'S7P',
#  'R5P',
#  'P5P',
#  'RUBP',
#  'G6P',
#  'F6P',
#  'G1P',
#  'FBP',
#  '2PG',
#  'Glycerate',
#  'PEP',
#  'ADPG',
#  'UDPG',
#  'Malate',
#  'Succinate',
#  'Fumarate',
#  'Aconitate',
#  'a-Ketoglutarate',
#  'Citrate',
#  'Ser',
#  'Gly',
#  'Asp',
#  'Ala',
#  'Pro',
#  'Thr',
#  'Asn',
#  'Glu',
#  'Gln',
#  't=60',
#  'Abbreviations',
#  'Reactions',
#  'Net fluxes',
#  'Exchange fluxes',
#  'Subcellular fluxes',
#  'Dilution Parameters',
#  'Pool Sizes']

# %% [markdown]
# In the data they authors describe a meta reaction called PhleomOut. This reaction as variable coefficients. In the following we define dictionary which describes which coefficient to use.

# %%
output_sink_ratios = {
    "α": "1", 
    "β":"1", 
    "γ":"1",
    "δ":"1",
    "ε":"1"
}

# %% [markdown]
# Now we are ready to read in the reactions and wrangle them into the correct format for the INCAWrapper.

# %%
reactions = (xl
    .parse('Reactions', skiprows=4, skipfooter=3)
    .rename(columns={
        "Calvin Cycle": "rxn_id", 
        "Unnamed: 1": "Substrate",
        "Unnamed: 2": "Arrow", 
        "Unnamed: 3": "Product"
    })
    .dropna(subset=["Arrow"]) # Removes section headers within the table
    .assign(
        Arrow= lambda x: x.Arrow.replace({"→":"->", "↔":"<->"})
    )
    .assign(
        rxn_eqn = lambda x: x.Substrate + " " + x.Arrow + " " + x.Product,
    )
    .drop(columns=["Substrate", "Arrow", "Product"])
)

# modify PhloemOut output sink reaction
reactions.loc[reactions.rxn_id == "PhloemOut", "rxn_eqn"] = (reactions
    .loc[reactions.rxn_id == "PhloemOut", "rxn_eqn"]
    .replace(
        output_sink_ratios, 
        regex=True
    )
    .replace(
        {"\(":"", "\)":""},
        regex=True
    )
)

dataschemas.ReactionsSchema.validate(reactions)
# Out:
#          rxn_id                                            rxn_eqn
# 0   RUBISCO_CO2  RUBP.p (abcde) + CO2 (f)  -> 3PGA.p (cde) + 3P...
# 1           ALD        TP.p (abc) + E4P.p (defg)  -> SBP (cbadefg)
# 2        SBPase                  SBP (abcdefg)  -> S7P.p (abcdefg)
# 3           TK1           TP.p (cde) + EC2 (ab)  <-> X5P.p (abcde)
# 4           TK2      S7P.p (abcdefg)  <-> R5P.p (cdefg) + EC2 (ab)
# 5           TK3        F6P.p (abcdef)  <-> E4P.p (cdef) + EC2 (ab)
# 6           PPE                  X5P.p (abcde)  <-> RU5P.p (abcde)
# 7           PPI                  R5P.p (abcde)  <-> RU5P.p (abcde)
# 8           PRK                  RU5P.p (abcde)  -> RUBP.p (abcde)
# 10   RUBISCO_O2       RUBP.p (abcde)  -> 3PGA.p (cde) + 2PG.p (ba)
# 11          PGP                          2PG.p (ab)  -> GLY.p (ab)
# 12       GLYdil                 GLY.p (ab) <-> GLY.x (ab) + GLYout
# 13          GDC  GLY.p (ab) + GLY.p (cd)  -> SER.p (cdb) + CO2 (a)
# 14       SERdil                 SER.p (ab) <-> SER.x (ab) + SERout
# 15         SGA1                         SER.p (abc)  -> GA.p (abc)
# 16           GK                       GA.p (abc)  <-> 3PGA.p (abc)
# 18      GAPDH.p                        3PGA.p (abc)  -> TP.p (abc)
# 19        FBA.p        TP.p (def) + TP.p (cba)  <-> FBP.p (abcdef)
# 20        PFP.p                 FBP.p (abcdef)  <-> F6P.p (abcdef)
# 21        PGI.p                 F6P.p (abcdef)  <-> G6P.p (abcdef)
# 22        PGM.p                 G6P.p (abcdef)  <-> G1P.p (abcdef)
# 23          AGP                   G1P.p (abcdef)  -> ADPG (abcdef)
# 24           SS                   ADPG (abcdef) -> Starch (abcdef)
# 26        FBA.c        TP.c (def) + TP.c (cba)  <-> FBP.c (abcdef)
# 27        PFP.c                 FBP.c (abcdef)  <-> F6P.c (abcdef)
# 28        PGI.c                 F6P.c (abcdef)  <-> G6P.c (abcdef)
# 29        PGM.c                 G6P.c (abcdef)  <-> G1P.c (abcdef)
# 30          GPU                  G1P.c (abcdef)  <-> UDPG (abcdef)
# 31          SPS  F6P.c (abcdef) + UDPG (ghijkl)  -> S6P (abcdef...
# 33       PGAM.c                       3PGA.c (abc) <-> PEP.c (abc)
# 34         PK.c                         PEP.c (abc) -> PYR.c (abc)
# 35          PDH                  PYR.C (abc) -> ACA (bc) + CO2 (a)
# 36           CS              OAA (abcd) + ACA (ef) -> CIT (dcbfea)
# 37          ACO                      CIT (abcdef) <-> ICI (abcdef)
# 38          IDH              ICI (abcdef) -> AKG (abcde) + CO2 (f)
# 39          MDH                          MAL (abcd) <-> OAA (abcd)
# 41          PPC                PEP.c (abc) + CO2 (d) -> OAA (abcd)
# 43          ALT                        PYR.c (abc)  -> ALA.c (abc)
# 44         ASPT                             OAA (abc) -> ASP (abc)
# 45        GLUDH                         AKG (abcde) -> GLU (abcde)
# 46          PCR                        GLU (abcde) <-> PRO (abcde)
# 47           GS                        GLU (abcde) <-> GLN (abcde)
# 48           TS                          ASP (abcd) <-> THR (abcd)
# 49           AS                          ASP (abcd) <-> ASN (abcd)
# 50    PhloemOut  S6P + 1GLU + 1ASP + 1ALA.c + 1GLYout + 1SERout...
# 52       T_3PGA                     3PGA.p (abc)  <-> 3PGA.c (abc)
# 53         T_TP                         TP.p (abc)  <-> TP.c (abc)

# %%
mdv_sheet = (xl.parse("Asp"))
mdv_sheet
# Out:
#     Mass isotopomer measured abundances.     Unnamed: 1  Unnamed: 2  \
# 0                                    NaN            NaN         NaN
# 1                               Compound  Labeling time         NaN
# 2                                ASP 316          (min)  Isotopomer
# 3                                    NaN              0        [M]+
# 4                                    NaN            NaN      [M+1]+
# ..                                   ...            ...         ...
# 151                                  NaN             15        [M]+
# 152                                  NaN            NaN      [M+1]+
# 153                                  NaN            NaN      [M+2]+
# 154                                  NaN            NaN      [M+3]+
# 155                                  NaN            NaN      [M+4]+
#
#                                   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                                        NaN        NaN        NaN        NaN
# 1                            LL experiment          NaN        NaN        NaN
# 2                                     Rep. 1     Rep. 2     Rep. 3     Rep. 1
# 3                                    5588302  5229444.8  4980139.2  5616415.7
# 4                                  1562679.1  1421519.9  1358543.2  1657950.5
# ..                                       ...        ...        ...        ...
# 151                                5779674.7  6033424.2  6160837.9  4713341.8
# 152                                  2329567  2533550.2  2638299.8    2050628
# 153                                1323153.2  1457488.1  1571362.2  1249858.6
# 154                                 759208.9   741771.3   851424.6   892230.3
# 155                                 763134.5   558426.6   709945.6  1016350.9
#
#             Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0                  NaN        NaN        NaN
# 1    HL-ACC experiment        NaN        NaN
# 2               Rep. 2     Rep. 3     Rep. 4
# 3              5705676   424875.7   509742.2
# 4            1602144.6   115772.6   140531.7
# ..                 ...        ...        ...
# 151          4198310.2          X   267147.9
# 152          1879604.5          X   106610.5
# 153          1063154.6          X    55248.4
# 154           707085.4          X    23129.3
# 155           682211.9          X    15929.3
#
# [156 rows x 10 columns]

# %%
from typing import List
def extract_mdv_table(sheet: pd.DataFrame)->List[pd.DataFrame]:
    """One sheet can contain multiple MDV tables. This function extracts 
    them all and returns a list of DataFrames.
    """
    tables = []
    table = []
    for i, row in sheet.iterrows():
        if row.isna().all():
            if len(table) > 0:
                tables.append(pd.DataFrame(table))
                table = []
        else:
            table.append(row)
    if len(table) > 0:
        tables.append(pd.DataFrame(table))
    return tables

mdv_tables = extract_mdv_table(mdv_sheet)
mdv_table = mdv_tables[0]
mdv_table.head()
# Out:
#   Mass isotopomer measured abundances.     Unnamed: 1  Unnamed: 2  \
# 1                             Compound  Labeling time         NaN
# 2                              ASP 316          (min)  Isotopomer
# 3                                  NaN              0        [M]+
# 4                                  NaN            NaN      [M+1]+
# 5                                  NaN            NaN      [M+2]+
#
#                                 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 1                          LL experiment          NaN        NaN        NaN
# 2                                   Rep. 1     Rep. 2     Rep. 3     Rep. 1
# 3                                  5588302  5229444.8  4980139.2  5616415.7
# 4                                1562679.1  1421519.9  1358543.2  1657950.5
# 5                                 595215.7   539683.7   518377.3   601837.8
#
#           Unnamed: 7 Unnamed: 8 Unnamed: 9
# 1  HL-ACC experiment        NaN        NaN
# 2             Rep. 2     Rep. 3     Rep. 4
# 3            5705676   424875.7   509742.2
# 4          1602144.6   115772.6   140531.7
# 5           639711.2    45061.2    54467.2

# %%
def convert_mass_isotope_to_int(mass_isotope: str)->int:
    """Converts mass_isotope str to an interger. Accepts strings like
    [M]+, [M+1]+ ...
    """
    if mass_isotope == "[M]+":
        return 0
    else:
        mass_isotope_int = mass_isotope.replace("[M+", "").replace("]+", "")
        return int(mass_isotope_int)


def tidy_mdv_table(mdv_table: pd.DataFrame, relative_error: float)->pd.DataFrame:
    ms_id = mdv_table.iloc[1,0]

    # manually preparing header 
    mdv_table.iloc[0,3:6] = 'LL experiment'
    mdv_table.iloc[0,6:10] = 'HL-ACC experiment'
    new_header = (mdv_table
        .iloc[:2]
        .fillna('')
        .apply(lambda row: "_".join(row)) #grab the first row for the header
        .reset_index(drop=True)
    )
    mdv_table.columns = new_header
    
    # remove header rows
    mdv_table = mdv_table.iloc[2:]

    tidy = (mdv_table
        .rename(
            columns={
                f"Compound_{ms_id}": "ms_id",
                "Labeling time_ (min)": "time",
                "_Isotopomer": "mass_isotope"
            }
        )
        .assign(ms_id = ms_id)
        .assign(time = lambda df: df.time.fillna(method="ffill"))
        .pipe(
            pd.wide_to_long,
            stubnames=["LL experiment", "HL-ACC experiment"],
            i=["ms_id", "time", "mass_isotope"],
            j="replicate",
            sep="_",
            suffix=r'.+'
        )
        .melt(ignore_index=False, var_name="experiment_id", value_name="intensity")
        .replace("X", np.nan)
        .reset_index()
        .assign(
            mass_isotope = lambda df: df.mass_isotope.apply(convert_mass_isotope_to_int),
        )
        .assign(
            metabolite_id = lambda df: df.ms_id.str.split(" ").str[0] # extract metabolite_id from ms_id
        )
        .assign(
            intensity_std_error = lambda df: df.intensity * relative_error # adding uncertainty 
        )
    )
    
    return tidy
tidy_mdv_table(mdv_table, 0.05)
# Out:
#        ms_id  time  mass_isotope replicate      experiment_id  intensity  \
# 0    ASP 316   0.0             0    Rep. 1      LL experiment  5588302.0
# 1    ASP 316   0.0             0    Rep. 2      LL experiment  5229444.8
# 2    ASP 316   0.0             0    Rep. 3      LL experiment  4980139.2
# 3    ASP 316   0.0             0    Rep. 4      LL experiment        NaN
# 4    ASP 316   0.0             1    Rep. 1      LL experiment  1562679.1
# ..       ...   ...           ...       ...                ...        ...
# 347  ASP 316  15.0             2    Rep. 4  HL-ACC experiment    41928.2
# 348  ASP 316  15.0             3    Rep. 1  HL-ACC experiment  1144723.9
# 349  ASP 316  15.0             3    Rep. 2  HL-ACC experiment   912355.2
# 350  ASP 316  15.0             3    Rep. 3  HL-ACC experiment        NaN
# 351  ASP 316  15.0             3    Rep. 4  HL-ACC experiment    23090.7
#
#     metabolite_id  intensity_std_error
# 0             ASP           279415.100
# 1             ASP           261472.240
# 2             ASP           249006.960
# 3             ASP                  NaN
# 4             ASP            78133.955
# ..            ...                  ...
# 347           ASP             2096.410
# 348           ASP            57236.195
# 349           ASP            45617.760
# 350           ASP                  NaN
# 351           ASP             1154.535
#
# [352 rows x 8 columns]
